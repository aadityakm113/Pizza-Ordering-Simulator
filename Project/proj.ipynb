# %% [markdown]
# Pizza Ordering simulator
#
# Database of different pizas with choice of size,crust and toppings
#
# selection interface
#
# Bill file
#
# three sizes small medium large
#
# toppings-chicken, olives, extra cheese, jalepenos, Pepperoni,Sausage
# user can choose max 3 toppings
#
# user table in sqlite
# price table in sqlite
# create user
# login
# order

# %%
List of variables used
conn
c
price #price dictionary
pricevalues #price list

#home screen
home #home screen
lab  # home label
SI # sign in button
SU #sign up button

#sign up screen
suw # sign up window function
signupwin #second screen
#labels
l #name label
l1 #username label
l2 #password label
l3 #repass label
l4 # ph no. label
#entries
name 
su_username
su_password
repass 
ph 
store #save button
save #save function
getus # get username
getpass#get password
getrepass#get repass
getph # get phone nunmber
values#list of retrieved info
elbl#error label


#sign in screen
l5#usesrname label
l6#password label

#Order page
l7 
l8

# %%
import tkinter 
from tkinter import *

window=Tk()
window.geometry("500x500")
window.title("Hello")


l1=Label(window,text='Hello good morning')
l1.pack_configure(anchor=CENTER)
l2=Label(window,text='This is another label')
l2.pack()
r=StringVar()
#r.set()
Radiobutton(window,text="hi",variable=r,value="hi").pack()
Radiobutton(window,text="hello",variable=r,value="hello").pack()
mylabel=Label(window,text=r.get()).pack()


def new():
    for widget in window.winfo_children():
            widget.destroy()
    window.geometry("300x120")
    newl=Label(window,text="This is the next page")
    newl.pack()

next=Button(window,text="Next Page",command=new)
next.pack()
window.mainloop()

# %%
import tkinter 
from tkinter import *

window=Tk()
window.geometry("500x500")
window.title("Hello")
user=Entry(window)
user.pack()
def show():
    see=user.get()
    lbl=Label(window,text=see)
    lbl.pack()
btn=Button(window,text="Click Me",command=show)
btn.pack()

window.mainloop()

# %%
from cProfile import label
from functools import partial
import sqlite3
import hashlib

import tkinter as tk
from tkinter import CENTER, Button, Entry, Label, Tk, filedialog, Text
from tkinter import *
import os
from tkinter import simpledialog

from matplotlib.pyplot import show
from numpy import size

#home screen
home=Tk()
home.title("Aadi's Pizzeria")
home.geometry("500x300")
lab = Label(home, text = "Welcome to Aadi's Pizzeria")
lab.pack()
SI=Button(home,text="Sign in",command=orderwin)
SU=Button(home,text="Sign up",command=suw)
SU.pack()
SI.pack()

#Order Window
def orderwin():
    for widget in home.winfo_children():
            widget.destroy()
    home.geometry("500x300")
    home.title("Order Your Pizza")

    orderfont=("",20,"bold")
    l7=Label(home,text="Order Your Pizza",anchor="center",font=orderfont)
    l7.pack()

    sizefont=("",14,"")
    l8=Label(home,text="Size",anchor="center",font=sizefont)
    l8.pack()

    r=StringVar()
    #r.set()
    a=Radiobutton(home,text="Small (₹99)",variable=r,value=99,anchor="w")
    a.deselect()
    a.pack()
    b=Radiobutton(home,text="Medium (₹199)",variable=r,value=199,anchor="center")
    b.deselect()
    b.pack()
    c=Radiobutton(home,text="Large (₹399)",variable=r,value=399,anchor="e")
    c.deselect()
    c.pack()

    toppingfont=("",14,"")
    l9=Label(home,text="Toppings",anchor="center",font=toppingfont)
    l9.pack()

    placeorder=Button(home,text="Place Order")
    placeorder.pack()




home.mainloop()

# %%
from msilib.schema import Font
from pkgutil import extend_path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tkinter
from tkinter import *
import sqlite3

#sign in window
signinwin=Toplevel()
signinwin.geometry("500x300")
signinwin.title("Sign in")

#Entering user details
l5=Label(signinwin,text="Enter Username: ")
l5.pack()
si_username=Entry(signinwin)
si_username.pack()
l6=Label(signinwin,text="Enter Password: ")
l6.pack()
si_password=Entry(signinwin)
si_password.pack()

#sign in button

home.mainloop()

# %%
c.execute("SELECT * FROM User WHERE Username='kart'")
data=c.fetchall()
conn.commit()
print(data[0][3])

# %%
'''
Pizza Ordering Simulator 
By Aaditya Kumar Muktavarapu
HU21CSEN0100580
amuktava@gitam.in
'''
from msilib.schema import Font
from pkgutil import extend_path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tkinter
from tkinter import *
import sqlite3

#Database Creation
conn=sqlite3.connect("Database.db")

#Cursor Creation
c=conn.cursor()

#Table Creation

#Pricing Table
c.execute("""
            CREATE TABLE IF NOT EXISTS Pricing("S.No" int,
            "Base/Topping" text,"Price" text)
            """)

#Price dictionary
price = {'Sausage': "₹40", 'Pepperoni': "₹40", 'Chicken': "₹40", 'Olives': "₹35",'Extra Cheese':'₹30','Jalepenos':"₹35"}
#Entering Values in Pricing Table
pricevalues=[
    ("1","Small","₹99"),
    ("2","Medium","₹199"),
    ("3","Large","₹399"),
    ("4","Olives","₹35"),
    ("5","Chicken","₹40"),
    ("6","Jalepenos","₹35"),
    ("7","Pepperoni","₹40"),
    ("8","Sausage","₹40"),
    ("9","Extra Cheese","30")
]
#c.executemany("INSERT into Pricing VALUES(?,?,?)",pricevalues)

#User Table
c.execute("""
            CREATE TABLE IF NOT EXISTS User("Phone number" int PRIMARY KEY,
            "Name" text,"Username" text, "Password" text)
            """)

conn.commit()

#home screen
home=Tk()
home.title("Aadi's Pizzeria")
home.geometry("500x300")
FONT=("Comic Sans MS",20,"bold")
lbl = Label(home, text = "Welcome to Aadi's Pizzeria",font=FONT)
lbl.pack()

#User Entries
l5=Label(home,text="Enter Username: ")
l5.pack()
si_username=Entry(home)
si_username.pack()
l6=Label(home,text="Enter Password: ")
l6.pack()
si_password=Entry(home)
si_password.pack()

#Order Window
def orderwin():
    for widget in home.winfo_children():
            widget.destroy()
    home.geometry("500x300")
    home.title("Order Your Pizza")

    orderfont=("",20,"bold")
    l7=Label(home,text="Order Your Pizza",anchor="center",font=orderfont)
    l7.pack()

    sizefont=("",14,"")
    l8=Label(home,text="Size",anchor="center",font=sizefont)
    l8.pack()

    r=StringVar()
    #r.set()
    a=Radiobutton(home,text="Small (₹99)",variable=r,value=99,anchor="w")
    a.deselect()
    a.pack()
    b=Radiobutton(home,text="Medium (₹199)",variable=r,value=199,anchor="center")
    b.deselect()
    b.pack()
    c=Radiobutton(home,text="Large (₹399)",variable=r,value=399,anchor="e")
    c.deselect()
    c.pack()

    toppingfont=("",14,"")
    l9=Label(home,text="Toppings",anchor="center",font=toppingfont)
    l9.pack()

    placeorder=Button(home,text="Place Order")
    placeorder.pack()



#Sign up Window
def suw():
    global signupwin
    signupwin=Toplevel()
    signupwin.geometry("500x300")
    signupwin.title("Create Account")
    
    #Text box to enter user details
    l=Label(signupwin,text="Enter Name: ")
    l.pack()
    name=Entry(signupwin)
    name.pack()
    l1=Label(signupwin,text="Enter Username: ")
    l1.pack()
    su_username=Entry(signupwin)
    su_username.pack()
    l2=Label(signupwin,text="Enter Password: ")
    l2.pack()
    su_password=Entry(signupwin)
    su_password.pack()
    l3=Label(signupwin,text="Re-enter your password: ")
    l3.pack()
    repass=Entry(signupwin)
    repass.pack()
    l4=Label(signupwin,text="Enter your Phone Number: ")
    l4.pack()
    ph=Entry(signupwin)
    ph.pack()
    

    #saving Details to database
    def save():
        
        getname=name.get()
        getus=su_username.get()
        getpass=su_password.get()
        getrepass=repass.get()
        getph=ph.get()
        
        values=(getph,getname,getus,getpass)
        if getpass==getrepass:
            c.execute("INSERT into User VALUES(?,?,?,?)",values)
            conn.commit()
            
                
        else:
            elbl=Label(signupwin,text="Passwords not Matching")
            elbl.pack()

        #ul=Label(signupwin,text=getus)
        #ul.pack()
    store=Button(signupwin,text="Save Details",command=save)
    store.pack()

#retrieving username and password from database and comparing with user inputted credentials
def check():
    getluser=si_username.get()
    getlpass=si_password.get()
    c.execute("SELECT * from User WHERE Username=(?)",(getluser,))
    data=c.fetchall()
    conn.commit()
    if getlpass==data[0][3]:
        #suclbl=Label(home,text="Success!")
        #suclbl.pack()
        orderwin()
    else:
        elbl1=Label(home,text="Invalid Credentials")
        elbl1.pack()

SI=Button(home,text="Sign in",command=check)
SI.pack()
SU=Button(home,text="Sign up",command=suw)
SU.pack()

home.mainloop()
